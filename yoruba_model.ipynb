# %% [markdown]
# <a href="https://colab.research.google.com/github/chimaOkwuokei/machine-learning-projects/blob/main/yoruba_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#model importation
# !pip install opencv-python-headless torch torchvision numpy
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
#other imports
# %cd yolov5
# %pip install -qr requirments.txt

import torch
from pathlib import Path
from IPython.display import Image, clear_output
import numpy as np
from google.colab.patches import cv2_imshow
import cv2

clear_output()


#we edit coco.yaml file from the data folder

# %%
# !unzip -q ../yoruba.zip -d ../
#made use of --make sense ai-- to create the 'border boxes'/labels

# %%
# Train YOLOv5s on COCOCUSTOM for 200 epochs
#image size, batch size, number of epochs

#for yoruba
#cache was corrupted, had to delete
# !python train.py --img 520 --batch 2 --epochs 250 --data coco_custom.yaml --weights yolov5s.pt --nosave --cache
# Out:
# 2024-06-07 20:29:57.120963: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 20:29:57.121021: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 20:29:57.122439: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#run                                 exp2 for yoruba                                #confidence score
# !python detect.py --weights /content/best.pt --img 512 --conf 0.4 --source ../17.jpeg


# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# Traceback (most recent call last):
#   File "/content/detect.py", line 46, in <module>
#     from ultralytics.utils.plotting import Annotator, colors, save_one_box
# ModuleNotFoundError: No module named 'ultralytics'
