# %% [markdown]
# <a href="https://colab.research.google.com/github/chimaOkwuokei/machine-learning-projects/blob/main/Yolov5_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#model importation
# !pip install opencv-python-headless torch torchvision numpy
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
#other imports
# %cd yolov5
# %pip install -qr requirments.txt

import torch
from pathlib import Path
from IPython.display import Image, clear_output
import numpy as np
from google.colab.patches import cv2_imshow
import cv2

clear_output()


#we edit coco.yaml file from the data folder

# %%
# !unzip -q ../train_data_car_landrover.zip -d ../
#made use of --make sense ai-- to create the 'border boxes'

# %%
# Train YOLOv5s on COCO128 for 3 epochs
#image size, batch size, number of epochs

#cache was corrupted, had to delete
# !python train.py --img 640 --batch 2 --epochs 90 --data coco_custom.yaml --weights yolov5s.pt --nosave --cache
# Out:
# 2024-04-17 21:34:27.303281: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-17 21:34:27.303342: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-17 21:34:27.304883: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#run                                                                    #confidence score
# !python detect.py --weights runs/train/exp4/weights/best.pt --img 640 --conf 0.35 --source ../video.mp4
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (105/5101) /content/video.mp4: 384x640 (no detections), 7.1ms
# video 1/1 (106/5101) /content/video.mp4: 384x640 (no detections), 7.2ms
# video 1/1 (107/5101) /content/video.mp4: 384x640 (no detections), 7.3ms
# video 1/1 (108/5101) /content/video.mp4: 384x640 (no detections), 6.8ms
# video 1/1 (109/5101) /content/video.mp4: 384x640 (no detections), 6.5ms
# video 1/1 (110/5101) /content/video.mp4: 384x640 (no detections), 7.2ms
# video 1/1 (111/5101) /content/video.mp4: 384x640 (no detections), 6.8ms
# video 1/1 (112/5101) /content/video.mp4: 384x640 (no detections), 7.1ms
# video 1/1 (113/5101) /content/video.mp4: 384x640 (no detections), 8.9ms
# video 1/1 (114/5101) /content/video.mp4: 384x640 (no detections), 6.5ms
# video 1/1 (115/5101) /content/video.mp4: 384x640 (no detections), 7.3ms
# video 1/1 (116/5101) /content/video.mp4: 384x640 (no detections), 6.9ms
# ...
